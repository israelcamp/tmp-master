# %%
import glob
import os
from PIL import Image
import xml.etree.ElementTree as ET

from tqdm.auto import tqdm
import srsly

# %%
IMAGES_DIR = "../data/SVT/img"
TRAIN_PATH = "../data/SVT/train.xml"
TEST_PATH = "../data/SVT/test.xml"

DEST_DIR = "../data/SVT/crop"

# %%
def parse_xml_to_data(xml_filepath):
    tree = ET.parse(xml_filepath)
    root = tree.getroot()

    data = {} # name to label
    for image in tqdm(root.findall("image")):
        image_name = image.find("imageName").text.split("/")[-1].replace(".jpg", "")
        tagged_rectangles = image.find("taggedRectangles").findall("taggedRectangle")

        # read image with PIL
        pil_img = Image.open(os.path.join(IMAGES_DIR, image_name + ".jpg"))

        for rectangle in tagged_rectangles:
            x = int(rectangle.get("x"))
            y = int(rectangle.get("y"))
            width = int(rectangle.get("width"))
            height = int(rectangle.get("height"))
            text = rectangle.find("tag").text

            # crop image
            cropped_img = pil_img.crop((x, y, x + width, y + height))

            # save image
            cropped_img.save(os.path.join(DEST_DIR, image_name + "_" + text + ".png"))

            # add to train data
            data[image_name + "_" + text] = text
    return data

# %%
train_data = parse_xml_to_data(TRAIN_PATH)
test_data = parse_xml_to_data(TEST_PATH)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 46.18it/s]
# 100%|██████████| 249/249 [00:04<00:00, 53.99it/s]

# %%
srsly.write_json("../data/SVT/train.json", train_data)
srsly.write_json("../data/SVT/test.json", test_data)

# %%
len(train_data), len(test_data)
# Out:
# (239, 569)

# %%
train_data
# Out:
# {'14_03_LIVING': 'LIVING',
#  '14_03_ROOM': 'ROOM',
#  '14_03_THEATERS': 'THEATERS',
#  '14_04_INSURANCE': 'INSURANCE',
#  '14_04_STANDARD': 'STANDARD',
#  '14_04_CENTER': 'CENTER',
#  '06_08_ANTIQUE': 'ANTIQUE',
#  '06_08_LULA': 'LULA',
#  '06_08_MALL': 'MALL',
#  '00_12_SUBWAY': 'SUBWAY',
#  '15_15_CHOCOLATE': 'CHOCOLATE',
#  '15_15_GHIRARDELLI': 'GHIRARDELLI',
#  '04_04_MASTER': 'MASTER',
#  '04_04_NAILS': 'NAILS',
#  '04_04_GLENOAK': 'GLENOAK',
#  '12_07_WINDSOR': 'WINDSOR',
#  '12_07_THE': 'THE',
#  '06_11_BANGKOK': 'BANGKOK',
#  '06_11_INN': 'INN',
#  '08_16_ALDEN': 'ALDEN',
#  '05_12_MAX': 'MAX',
#  '05_12_TOWING': 'TOWING',
#  '00_08_MARBLE': 'MARBLE',
#  '00_08_YARD': 'YARD',
#  '00_08_ORION': 'ORION',
#  '00_08_TILE': 'TILE',
#  '00_01_ASTORIA': 'ASTORIA',
#  '00_01_BEST': 'BEST',
#  '00_01_INN': 'INN',
#  '00_01_SUITES': 'SUITES',
#  '00_01_VALUE': 'VALUE',
#  '01_10_PAYLESS': 'PAYLESS',
#  '01_10_SHOE': 'SHOE',
#  '01_10_SOURCE': 'SOURCE',
#  '03_19_MOUNTS': 'MOUNTS',
#  '03_19_ROCKY': 'ROCKY',
#  '00_09_GOODWILL': 'GOODWILL',
#  '16_19_AMOEBA': 'AMOEBA',
#  '16_19_MUSIC': 'MUSIC',
#  '02_19_ARCADE': 'ARCADE',
#  '02_19_BROWN': 'BROWN',
#  '12_11_BELLA': 'BELLA',
#  '12_11_VISTA': 'VISTA',
#  '12_11_INC': 'INC',
#  '00_14_HOUSE': 'HOUSE',
#  '00_14_ORIGINAL': 'ORIGINAL',
#  '00_14_PANCAKE': 'PANCAKE',
#  '09_06_LIVING': 'LIVING',
#  '09_06_LOUNGE': 'LOUNGE',
#  '09_06_ROOM': 'ROOM',
#  '02_04_CAMDEN': 'CAMDEN',
#  '02_04_PUB': 'PUB',
#  '03_10_MACY': 'MACY',
#  '18_12_REI': 'REI',
#  '15_02_HOUSE': 'HOUSE',
#  '15_02_YARD': 'YARD',
#  '14_16_EVERYDAY': 'EVERYDAY',
#  '14_16_MUSIC': 'MUSIC',
#  '03_08_TIMBERLINE': 'TIMBERLINE',
#  '06_05_MAI': 'MAI',
#  '06_05_RESTAURANT': 'RESTAURANT',
#  '06_05_VIETNAMESE': 'VIETNAMESE',
#  '01_02_SOL': 'SOL',
#  '09_04_SHAKE': 'SHAKE',
#  '09_04_STEAK': 'STEAK',
#  '14_15_GENIES': 'GENIES',
#  '16_09_SING': 'SING',
#  '16_09_YANK': 'YANK',
#  '11_14_DETROIT': 'DETROIT',
#  '11_14_JOES': 'JOES',
#  '11_14_ORIGINAL': 'ORIGINAL',
#  '11_14_CONEY': 'CONEY',
#  '17_04_GOMBEI': 'GOMBEI',
#  '04_03_BARBER': 'BARBER',
#  '04_03_MODERN': 'MODERN',
#  '08_01_DEPARTMENT': 'DEPARTMENT',
#  '08_01_HOUSTON': 'HOUSTON',
#  '08_01_POLICE': 'POLICE',
#  '08_06_CONEY': 'CONEY',
#  '08_06_ISLAND': 'ISLAND',
#  '08_06_JAMES': 'JAMES',
#  '08_06_SIGNS': 'SIGNS',
#  '06_04_SAVE': 'SAVE',
#  '06_04_WAY': 'WAY',
#  '09_02_INN': 'INN',
#  '09_02_DAYS': 'DAYS',
#  '09_09_NIGHT': 'NIGHT',
#  '09_09_THERAPY': 'THERAPY',
#  '09_09_LOUNGE': 'LOUNGE',
#  '17_19_ANNO': 'ANNO',
#  '17_19_DOMINI': 'DOMINI',
#  '16_00_FRANCISCO': 'FRANCISCO',
#  '16_00_GRAND': 'GRAND',
#  '16_00_HYATT': 'HYATT',
#  '16_00_SAN': 'SAN',
#  '13_05_PORTAL': 'PORTAL',
#  '07_14_BROWN': 'BROWN',
#  '07_14_HOTEL': 'HOTEL',
#  '07_14_PALACE': 'PALACE',
#  '07_14_SPA': 'SPA',
#  '07_14_AND': 'AND',
#  '07_14_COMFORT': 'COMFORT',
#  '07_14_INN': 'INN',
#  '08_19_MACYS': 'MACYS',
#  '17_11_MIRAIDO': 'MIRAIDO',
#  '17_11_VILLAGE': 'VILLAGE',
#  '07_05_DOMINO': 'DOMINO',
#  '07_05_BENDERS': 'BENDERS',
#  '07_11_HILL': 'HILL',
#  '07_11_INN': 'INN',
#  '07_11_NOB': 'NOB',
#  '07_00_BOOKS': 'BOOKS',
#  '07_00_CAPITOL': 'CAPITOL',
#  '07_00_HILL': 'HILL',
#  '14_00_PGE': 'PGE',
#  '14_00_PARK': 'PARK',
#  '05_09_MARKET': 'MARKET',
#  '05_09_WORLD': 'WORLD',
#  '05_09_MICHAEL': 'MICHAEL',
#  '05_09_THE': 'THE',
#  '05_09_ARTS': 'ARTS',
#  '05_09_CRAFTS': 'CRAFTS',
#  '05_09_FITNESS': 'FITNESS',
#  '16_05_AMERICANIA': 'AMERICANIA',
#  '16_05_BEST': 'BEST',
#  '16_05_WESTERN': 'WESTERN',
#  '16_05_HOTEL': 'HOTEL',
#  '06_01_CAFE': 'CAFE',
#  '06_01_GARDEN': 'GARDEN',
#  '17_12_MARU': 'MARU',
#  '17_12_SUSHI': 'SUSHI',
#  '09_05_COMPLEXIONS': 'COMPLEXIONS',
#  '02_14_CHIAPPARELLI': 'CHIAPPARELLI',
#  '16_03_WARFIELD': 'WARFIELD',
#  '05_08_CHINATOWN': 'CHINATOWN',
#  '05_08_HOTEL': 'HOTEL',
#  '06_15_DAY': 'DAY',
#  '06_15_PHYSICIANS': 'PHYSICIANS',
#  '06_15_SURGERY': 'SURGERY',
#  '15_16_CENTER': 'CENTER',
#  '15_16_DIEGO': 'DIEGO',
#  '15_16_SAN': 'SAN',
#  '15_14_COMFORT': 'COMFORT',
#  '15_14_GASLAMP': 'GASLAMP',
#  '15_14_INN': 'INN',
#  '12_19_PLAYERS': 'PLAYERS',
#  '12_19_PLAYS': 'PLAYS',
#  '08_02_STARBUCKS': 'STARBUCKS',
#  '08_15_FOUR': 'FOUR',
#  '08_15_SEASONS': 'SEASONS',
#  '14_11_OUTDOOR': 'OUTDOOR',
#  '14_11_STORE': 'STORE',
#  '13_18_PORTLAND': 'PORTLAND',
#  '13_18_RESTAURANT': 'RESTAURANT',
#  '13_18_BAR': 'BAR',
#  '06_02_BAR': 'BAR',
#  '06_02_BLUE': 'BLUE',
#  '06_02_COLLAR': 'COLLAR',
#  '06_02_THE': 'THE',
#  '15_01_EMBASSY': 'EMBASSY',
#  '15_01_SUITES': 'SUITES',
#  '14_19_BREW': 'BREW',
#  '14_19_LABRADOR': 'LABRADOR',
#  '14_19_LUCKY': 'LUCKY',
#  '14_19_PUB': 'PUB',
#  '09_17_CROWNE': 'CROWNE',
#  '09_17_PLAZA': 'PLAZA',
#  '09_17_HOTEL': 'HOTEL',
#  '13_09_BENTO': 'BENTO',
#  '13_09_YASDA': 'YASDA',
#  '00_00_DOLL': 'DOLL',
#  '00_00_HUT': 'HUT',
#  '16_10_BIERSCH': 'BIERSCH',
#  '16_10_BREWERY': 'BREWERY',
#  '16_10_GORDON': 'GORDON',
#  '16_10_RESTAURANT': 'RESTAURANT',
#  '17_01_DAKAO': 'DAKAO',
#  '17_01_RESTAURANT': 'RESTAURANT',
#  '04_15_GARIBYAN': 'GARIBYAN',
#  '04_15_MELANYA': 'MELANYA',
#  '04_15_CLEANING': 'CLEANING',
#  '04_15_PLACE': 'PLACE',
#  '16_08_BACAR': 'BACAR',
#  '02_11_THAIRISH': 'THAIRISH',
#  '02_11_THAI': 'THAI',
#  '06_14_LABYRINTH': 'LABYRINTH',
#  '15_18_SYMPHONY': 'SYMPHONY',
#  '15_18_HALL': 'HALL',
#  '01_18_QUALITY': 'QUALITY',
#  '01_18_HOTEL': 'HOTEL',
#  '08_10_MCKINNEY': 'MCKINNEY',
#  '10_02_DONUTS': 'DONUTS',
#  '10_02_DUNKIN': 'DUNKIN',
#  '10_02_COFFEE': 'COFFEE',
#  '07_16_TRAX': 'TRAX',
#  '07_16_WAX': 'WAX',
#  '07_16_RECORDS': 'RECORDS',
#  '09_08_IRVING': 'IRVING',
#  '09_08_WASHINGTON': 'WASHINGTON',
#  '09_08_SCHOOL': 'SCHOOL',
#  '18_14_LOLA': 'LOLA',
#  '16_07_BURMA': 'BURMA',
#  '16_07_SUPERSTAR': 'SUPERSTAR',
#  '18_05_QUINN': 'QUINN',
#  '01_09_NICK': 'NICK',
#  '03_07_BREWERY': 'BREWERY',
#  '03_07_WALNUT': 'WALNUT',
#  '15_07_CROCE': 'CROCE',
#  '15_07_RESTAURANT': 'RESTAURANT',
#  '05_03_FOODS': 'FOODS',
#  '05_03_MARKET': 'MARKET',
#  '05_03_WHOLE': 'WHOLE',
#  '02_07_DELICIOUS': 'DELICIOUS',
#  '02_07_GIGI': 'GIGI',
#  '02_07_JUST': 'JUST',
#  '06_06_CENTER': 'CENTER',
#  '06_06_CITYPLACE': 'CITYPLACE',
#  '02_12_BALTIMORE': 'BALTIMORE',
#  '02_12_SCORES': 'SCORES',
#  '03_13_DOLAN': 'DOLAN',
#  '18_11_EXECUTIVE': 'EXECUTIVE',
#  '18_11_HOTEL': 'HOTEL',
#  '18_11_PACIFIC': 'PACIFIC',
#  '18_11_THE': 'THE',
#  '15_13_MAN': 'MAN',
#  '15_13_MUSEUM': 'MUSEUM',
#  '15_09_BAYSIDE': 'BAYSIDE',
#  '15_09_BEST': 'BEST',
#  '15_09_WESTERN': 'WESTERN',
#  '15_09_INN': 'INN',
#  '05_07_GAMESTOP': 'GAMESTOP',
#  '11_11_ARTS': 'ARTS',
#  '11_11_BOB': 'BOB',
#  '11_11_CARR': 'CARR',
#  '11_11_CENTER': 'CENTER',
#  '11_11_PERFORMING': 'PERFORMING',
#  '11_11_ORLANDO': 'ORLANDO',
#  '04_16_BLOCKBUSTER': 'BLOCKBUSTER',
#  '04_16_VIDEO': 'VIDEO'}
